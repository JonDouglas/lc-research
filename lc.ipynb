# %%
# !pip3 install biopython python-dateutil
# Out:
# Requirement already satisfied: biopython in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (1.84)
# Requirement already satisfied: python-dateutil in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.9.0.post0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from biopython) (1.26.4)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
from pubmed_preprint_search import combine_and_display_results
from Bio import Entrez

# Set your email for Entrez
Entrez.email = "your.email@example.com"

queries = ["long covid", "sars-cov-2"]
combine_and_display_results(queries, page=1, results_per_page=200)
# Out:
#     <h3>Search terms: long covid, sars-cov-2</h3>
#     <p>698 total results</p>
#     <p>Page 1</p>
#     <p>Timeframe: All time</p>
#
#         <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#
#                 <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#                     <h3>Associates of Neutrophil/lymphocyte Ratio in Patients with COVID 19 Infection: A Single Center Experience</h3>
#                     <p><strong>Authors:</strong> B. Turan, E. Baysal, C. Ömür et al.</p>
#                     <p><strong>Server:</strong> ResearchSquare</p>
#                     <p><strong>Date:</strong> 2024-11-08</p>
#                     <p><strong>Link:</strong> <a href="https://www.researchsquare.com/article/rs-5338049/v1" target="_blank">ResearchSquare Link</a></p>
#                 </div>
#
#             <p><strong>Matching Queries:</strong> long covid</p>
#         </div>
#
#         <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#
#                 <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#                     <h3>How Long-term Care Insurance Coverage of Dementia would Impact Healthcare Utilization and Expenditure of People with Disability and Dementia: A Triple Difference Analysis.</h3>
#                     <p><strong>Authors:</strong> Qianyu He, Yujing Zhou, Bei Ye et al.</p>
#                     <p><strong>Server:</strong> ResearchSquare</p>
#                     <p><strong>Date:</strong> 2024-11-08</p>
#                     <p><strong>Link:</strong> <a href="https://www.researchsquare.com/article/rs-5347486/v1" target="_blank">ResearchSquare Link</a></p>
#                 </div>
#
#             <p><strong>Matching Queries:</strong> long covid</p>
#         </div>
#
#         <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#
#                 <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#                     <h3>Moral Distress and Compassion Fatigue Among Healthcare Workers During the COVID-19 Pandemic: The Moderating Role of Organizational Support</h3>
#                     <p><strong>Authors:</strong> Xin Quan, Pei-Fen Li, Christopher Burnett</p>
#                     <p><strong>Server:</strong> ResearchSquare</p>
#                     <p><strong>Date:</strong> 2024-11-08</p>
#                     <p><strong>Link:</strong> <a href="https://www.researchsquare.com/article/rs-5285302/v1" target="_blank">ResearchSquare Link</a></p>
#                 </div>
#
#             <p><strong>Matching Queries:</strong> long covid</p>
#         </div>
#
#         <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#
#                 <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#                     <h3>In Vitro Evaluation of Silver-Zinc Oxide-Eugenol Nanocomposite for Enhanced Antimicrobial and Wound Healing Applications in Diabetic Conditions</h3>
#                     <p><strong>Authors:</strong> Karutha Pandian Shunmugiah</p>
#                     <p><strong>Server:</strong> ResearchSquare</p>
#                     <p><strong>Date:</strong> 2024-11-08</p>
#                     <p><strong>Link:</strong> <a href="https://www.researchsquare.com/article/rs-4916104/v1" target="_blank">ResearchSquare Link</a></p>
#                 </div>
#
#             <p><strong>Matching Queries:</strong> sars-cov-2</p>
#         </div>
#
#         <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#
#                 <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#                     <h3>Long-term maintenance of regenerative agriculture enhances soil food webs and drives carbon accumulation</h3>
#                     <p><strong>Authors:</strong> Tvisha Martin, Christine Sprunger</p>
#                     <p><strong>Server:</strong> ResearchSquare</p>
#                     <p><strong>Date:</strong> 2024-11-08</p>
#                     <p><strong>Link:</strong> <a href="https://www.researchsquare.com/article/rs-5277440/v1" target="_blank">ResearchSquare Link</a></p>
#                 </div>
#
#             <p><strong>Matching Queries:</strong> long covid</p>
#         </div>
#
#         <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#
#                 <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#                     <h3>Efficacy and Safety of Vonoprazan as Treatment and Long-term Management of Peptic Ulcer: A Systematic Review and Meta-Analysis</h3>
#                     <p><strong>Authors:</strong> Valeria Chiara Lanari, Karthikeyan Govindarajan, Munazza Iftikhar et al.</p>
#                     <p><strong>Server:</strong> ResearchSquare</p>
#                     <p><strong>Date:</strong> 2024-11-08</p>
#                     <p><strong>Link:</strong> <a href="https://www.researchsquare.com/article/rs-5397106/v1" target="_blank">ResearchSquare Link</a></p>
#                 </div>
#
#             <p><strong>Matching Queries:</strong> long covid</p>
#         </div>
#
#         <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#
#                 <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#                     <h3>Nano-sized heterogeneous photocatalyst Fe 3 O 4 @V/TiO 2 -catalyzed synthesis and antimicrobial evaluation of 2-substituted benzimidazoles</h3>
#                     <p><strong>Authors:</strong> Lijian Bao, Xiaodong Chen, Yanli Li et al.</p>
#                     <p><strong>Server:</strong> ResearchSquare</p>
#                     <p><strong>Date:</strong> 2024-11-08</p>
#                     <p><strong>Link:</strong> <a href="https://www.researchsquare.com/article/rs-5354441/v1" target="_blank">ResearchSquare Link</a></p>
#                 </div>
#
#             <p><strong>Matching Queries:</strong> sars-cov-2</p>
#         </div>
#
#         <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#
#                 <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#                     <h3>Perceptions and Acceptance of herbal medicine Utilization among The Egyptian Population during the COVID-19 pandemic</h3>
#                     <p><strong>Authors:</strong> Doaa G. El-Hosari, Marwa O. Elgendy, Sara O. Elgendy et al.</p>
#                     <p><strong>Server:</strong> ResearchSquare</p>
#                     <p><strong>Date:</strong> 2024-11-08</p>
#                     <p><strong>Link:</strong> <a href="https://www.researchsquare.com/article/rs-5130272/v1" target="_blank">ResearchSquare Link</a></p>
#                 </div>
#
#             <p><strong>Matching Queries:</strong> long covid</p>
#         </div>
#
#         <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#
#                 <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#                     <h3>Beyond the Decade: Unveiling Long-Term Weight and Co- Morbidity Outcomes up to 10 Years Post Laparoscopic Sleeve Gastrectomy</h3>
#                     <p><strong>Authors:</strong> Salman Al Sabah, Eliana Al Haddad, Iman Qadhi et al.</p>
#                     <p><strong>Server:</strong> ResearchSquare</p>
#                     <p><strong>Date:</strong> 2024-11-08</p>
#                     <p><strong>Link:</strong> <a href="https://www.researchsquare.com/article/rs-5299255/v1" target="_blank">ResearchSquare Link</a></p>
#                 </div>
#
#             <p><strong>Matching Queries:</strong> long covid</p>
#         </div>
#
#         <div style="margin-bottom: 20px; padding: 10px; background-color: #8FBC8F;">
#
#                 <div style="margin-bottom
